# %%
import pandas as pd
import json
import datetime as dt
import numpy as np
from bs4 import BeautifulSoup
import traceback
import os
import time
from poi_funcs import *

# %%
def replace_text(text):
    replaces = [' ', '\t', '\n', '\r', '/', '\\']
    for r in replaces:
        text = text.replace(r, '')
    return text

def get_json(wd, city, pn):
    url_0 = 'http://map.baidu.com/?newmap=1&reqflag=pcmap&biz=1&\
    from=webmap&da_par=direct&pcevaname=pc4.1&qt=s&da_src=searchBox.\
    button&wd=@@wd&c=@@city&pn=@@pn'
    
    url = url_0.replace('@@wd', str(wd)).replace('@@city', str(city)).replace('@@pn', str(pn))
    return json.loads(get_res(url))

# %%
def get_soup(city_en):
    url_city = 'http://poi.mapbar.com/' + city_en
    return BeautifulSoup(get_res(url_city), 'lxml')

# %%
def get_city_top(city_en):
    bs4 = get_soup(city_en)
    raw_a_list = []
    for box in bs4.findAll('div', {'class':'isortBox'}):
        raw_a_list += box.findAll('a')
    values = []
    for a in raw_a_list:
        if 'http://poi.mapbar.com/' + city_en + '/' in a['href']:
            values.append([a.text, a['href']])
    df = pd.DataFrame(values, columns=['topic', 'url'])
    df.to_excel('/data/%s_top.xlsx' % city_en)
    return df

def get_entity_url(url):
    print(url)
    bs4 = BeautifulSoup(get_res(url), 'lxml')
    values = []
    all_a = bs4.find('div', {'class':'sortC'})
    if not all_a:
        print('error url: %s' % url)
        time.sleep(30)
        return None
    for a in all_a.findAll('a'):
        values.append([a.text, a['href']])
    df = pd.DataFrame(values, columns=['entity', 'url'])
    return df
    
def get_entity_info(entity, url):
    try:
        bs4 = BeautifulSoup(get_res(url), 'lxml')
    except:
        traceback.print_exc()
        return {}
    raw_basic_info = bs4.find('ul', {'class':'POI_ulA'})

    try:
        update_time = replace_text(raw_basic_info.find('li').text.split('：')[-1])
        year = int(update_time.split('年')[0])
        month = int(update_time.split('年')[1].split('月')[0])
        day = int(update_time.split('年')[1].split('月')[1].split('日')[0])
        update_time = dt.date(year, month, day).strftime('%Y-%m-%d')

    except:
        update_time = None
    try:
        address_items = raw_basic_info.find('li').find_next_sibling()
        address = [a.text for a in address_items.findAll('a')] +\
                [replace_text(address_items.text).split('：')[-1]]
    except:
        address = []

    try:
        raw_tel = raw_basic_info.find('li', {'class':'telCls'}).text.replace('\t', 
                '').replace('\r', '').split('\n')
        tel = [x for x in raw_tel if len(x) > 0][1]
        if tel == '我来添加':
            tel = None
    except:
        tel = None
    try:
        raw_traffics = bs4.find('div', {'class':'POI_Map'}).findAll('p')[:2]
        stations = replace_text(raw_traffics[0].text).split('、')
        lines = replace_text(raw_traffics[1].text).split('、')

        stations[-1] = stations[-1].replace('。', '')
        lines[-1] = lines[-1].replace('。', '')

        if stations[-1][-1] == '等':
            stations[-1] = stations[-1][:-1]
        if lines[-1][-1] == '等':
            lines[-1] = lines[-1][:-1]
    except:
        stations, lines = [], []

    keys = ['entity', 'update_time', 'address', 'tel', 'bus_stations', 'bus_lines']
    values = [entity, update_time, address, tel, stations, lines]
    return {k: v for k, v in zip(keys, values)}

# %%
def get_topic_dict(city_en):
    path = os.getcwd() + '/data/' + city_en + '/top_level/'
    df_top = get_city_top(city_en)
    topics, urls = df_top['topic'].tolist(), df_top['url'].tolist()
    topic_dict = {replace_text(topic):get_entity_url(url)
                 for topic, url in zip(topics, urls)}
    for topic, df_topic in topic_dict.items():
        try:
            df_topic.to_excel('%stopic_%s.xlsx' % (path, topic))
        except:
            traceback.print_exc()
    return topic_dict

# %%
def get_city_info(topic_dict):
    topics = list(topic_dict.keys())
    columns = ['entity', 'update_time', 'address', 
               'tel', 'bus_stations', 'bus_lines']

    path = os.getcwd() + '/data/' + city_en 
    if not os.path.exists(path):
        os.makedirs(path)

    for topic in topics:
        file_name = '%s/%s.xlsx' % (path, topic)
        if os.path.exists(file_name):
            continue
        df = topic_dict[topic]
        if len(df) == 0:
            continue
        values = []
        for ix in df.index:
            entity = df.at[ix, 'entity']
            url = df.at[ix, 'url']
            entity_info = get_entity_info(entity, url)
            if len(entity_info) == 0:
                continue
            values.append([entity_info[col] for col in columns])
            if ix % 100 == 0:
                progress = '{:.2%}'.format(ix / len(df))
                print('%s:%s' %(topic, progress))
        df_entity = pd.DataFrame(values, columns=columns)
        df_entity.to_excel(file_name)

# %%
topic_dict = get_topic_dict('nanjing')
# Out:
# http://poi.mapbar.com/nanjing/901/
# http://poi.mapbar.com/nanjing/910/
# http://poi.mapbar.com/nanjing/920/
# http://poi.mapbar.com/nanjing/930/
# http://poi.mapbar.com/nanjing/940/
# http://poi.mapbar.com/nanjing/950/
# http://poi.mapbar.com/nanjing/960/
# http://poi.mapbar.com/nanjing/980/
# http://poi.mapbar.com/nanjing/9A0/
# http://poi.mapbar.com/nanjing/9A1/
# http://poi.mapbar.com/nanjing/9C0/
# http://poi.mapbar.com/nanjing/9D0/
# http://poi.mapbar.com/nanjing/9E0/
# http://poi.mapbar.com/nanjing/9F0/
# http://poi.mapbar.com/nanjing/9F1/
# http://poi.mapbar.com/nanjing/9G0/
# http://poi.mapbar.com/nanjing/9Q0/
# http://poi.mapbar.com/nanjing/9R0/
# http://poi.mapbar.com/nanjing/9S0/
# http://poi.mapbar.com/nanjing/110/
# http://poi.mapbar.com/nanjing/120/
# http://poi.mapbar.com/nanjing/130/
# http://poi.mapbar.com/nanjing/140/
# http://poi.mapbar.com/nanjing/150/
# http://poi.mapbar.com/nanjing/151/
# http://poi.mapbar.com/nanjing/160/
# http://poi.mapbar.com/nanjing/180/
# http://poi.mapbar.com/nanjing/190/
# http://poi.mapbar.com/nanjing/1A0/
# http://poi.mapbar.com/nanjing/1B0/
# http://poi.mapbar.com/nanjing/211/
# http://poi.mapbar.com/nanjing/221/
# http://poi.mapbar.com/nanjing/222/
# http://poi.mapbar.com/nanjing/223/
# http://poi.mapbar.com/nanjing/230/
# http://poi.mapbar.com/nanjing/240/
# http://poi.mapbar.com/nanjing/241/
# http://poi.mapbar.com/nanjing/250/
# http://poi.mapbar.com/nanjing/251/
# http://poi.mapbar.com/nanjing/260/
# http://poi.mapbar.com/nanjing/270/
# http://poi.mapbar.com/nanjing/271/
# http://poi.mapbar.com/nanjing/272/
# http://poi.mapbar.com/nanjing/290/
# http://poi.mapbar.com/nanjing/2B0/
# http://poi.mapbar.com/nanjing/2C0/
# http://poi.mapbar.com/nanjing/2D0/
# http://poi.mapbar.com/nanjing/520/
# http://poi.mapbar.com/nanjing/530/
# http://poi.mapbar.com/nanjing/541/
# http://poi.mapbar.com/nanjing/542/
# http://poi.mapbar.com/nanjing/543/
# http://poi.mapbar.com/nanjing/544/
# http://poi.mapbar.com/nanjing/545/
# http://poi.mapbar.com/nanjing/546/
# http://poi.mapbar.com/nanjing/547/
# http://poi.mapbar.com/nanjing/548/
# http://poi.mapbar.com/nanjing/550/
# http://poi.mapbar.com/nanjing/560/
# http://poi.mapbar.com/nanjing/561/
# http://poi.mapbar.com/nanjing/570/
# http://poi.mapbar.com/nanjing/580/
# http://poi.mapbar.com/nanjing/581/
# http://poi.mapbar.com/nanjing/591/
# http://poi.mapbar.com/nanjing/5A0/
# http://poi.mapbar.com/nanjing/5B0/
# http://poi.mapbar.com/nanjing/5D0/
# http://poi.mapbar.com/nanjing/5D1/
# http://poi.mapbar.com/nanjing/5D2/
# http://poi.mapbar.com/nanjing/5D3/
# http://poi.mapbar.com/nanjing/5G0/
# http://poi.mapbar.com/nanjing/5I0/
# http://poi.mapbar.com/nanjing/5J0/
# http://poi.mapbar.com/nanjing/5K0/
# http://poi.mapbar.com/nanjing/350/
# http://poi.mapbar.com/nanjing/3B0/
# http://poi.mapbar.com/nanjing/3C0/
# http://poi.mapbar.com/nanjing/3D0/
# http://poi.mapbar.com/nanjing/3E0/
# http://poi.mapbar.com/nanjing/610/
# http://poi.mapbar.com/nanjing/630/
# http://poi.mapbar.com/nanjing/640/
# http://poi.mapbar.com/nanjing/650/
# http://poi.mapbar.com/nanjing/670/
# http://poi.mapbar.com/nanjing/691/
# http://poi.mapbar.com/nanjing/69A/
# http://poi.mapbar.com/nanjing/69B/
# http://poi.mapbar.com/nanjing/69C/
# http://poi.mapbar.com/nanjing/710/
# http://poi.mapbar.com/nanjing/711/
# http://poi.mapbar.com/nanjing/730/
# http://poi.mapbar.com/nanjing/740/
# http://poi.mapbar.com/nanjing/750/
# http://poi.mapbar.com/nanjing/781/
# http://poi.mapbar.com/nanjing/79A/
# http://poi.mapbar.com/nanjing/79B/
# http://poi.mapbar.com/nanjing/I10/
# http://poi.mapbar.com/nanjing/I20/
# http://poi.mapbar.com/nanjing/I30/
# http://poi.mapbar.com/nanjing/I40/
# http://poi.mapbar.com/nanjing/E10/
# http://poi.mapbar.com/nanjing/E20/
# http://poi.mapbar.com/nanjing/E22/
# http://poi.mapbar.com/nanjing/E40/
# http://poi.mapbar.com/nanjing/E50/
# http://poi.mapbar.com/nanjing/E60/
# http://poi.mapbar.com/nanjing/H10/
# http://poi.mapbar.com/nanjing/H50/
# http://poi.mapbar.com/nanjing/H70/
# http://poi.mapbar.com/nanjing/H83/
# http://poi.mapbar.com/nanjing/H90/
# http://poi.mapbar.com/nanjing/H91/
# http://poi.mapbar.com/nanjing/C01/
# http://poi.mapbar.com/nanjing/C03/
# http://poi.mapbar.com/nanjing/C10/
# http://poi.mapbar.com/nanjing/C30/
# http://poi.mapbar.com/nanjing/C40/
# http://poi.mapbar.com/nanjing/C50/
# http://poi.mapbar.com/nanjing/C60/
# http://poi.mapbar.com/nanjing/C91/
# http://poi.mapbar.com/nanjing/CB0/
# http://poi.mapbar.com/nanjing/CD0/
# http://poi.mapbar.com/nanjing/CE0/
# http://poi.mapbar.com/nanjing/CE1/
# http://poi.mapbar.com/nanjing/CE2/
# http://poi.mapbar.com/nanjing/CF0/
# http://poi.mapbar.com/nanjing/A10/
# http://poi.mapbar.com/nanjing/A20/
# http://poi.mapbar.com/nanjing/A21/
# http://poi.mapbar.com/nanjing/A30/
# http://poi.mapbar.com/nanjing/A40/
# http://poi.mapbar.com/nanjing/A41/
# http://poi.mapbar.com/nanjing/A50/
# http://poi.mapbar.com/nanjing/A60/
# http://poi.mapbar.com/nanjing/A61/
# http://poi.mapbar.com/nanjing/A70/
# http://poi.mapbar.com/nanjing/A90/
# http://poi.mapbar.com/nanjing/A91/
# http://poi.mapbar.com/nanjing/AA0/
# http://poi.mapbar.com/nanjing/AB0/
# http://poi.mapbar.com/nanjing/AC1/
# http://poi.mapbar.com/nanjing/AD0/
# http://poi.mapbar.com/nanjing/AE0/
# http://poi.mapbar.com/nanjing/AE1/
# http://poi.mapbar.com/nanjing/AH0/
# http://poi.mapbar.com/nanjing/AI0/
# http://poi.mapbar.com/nanjing/AJ0/
# http://poi.mapbar.com/nanjing/AK0/
# http://poi.mapbar.com/nanjing/D20/
# http://poi.mapbar.com/nanjing/D30/
# http://poi.mapbar.com/nanjing/D50/
# http://poi.mapbar.com/nanjing/D60/
# http://poi.mapbar.com/nanjing/D70/
# http://poi.mapbar.com/nanjing/D80/
# http://poi.mapbar.com/nanjing/DA0/
# http://poi.mapbar.com/nanjing/DB1/
# http://poi.mapbar.com/nanjing/DD0/
# http://poi.mapbar.com/nanjing/440/
# http://poi.mapbar.com/nanjing/F10/
# http://poi.mapbar.com/nanjing/F11/
# http://poi.mapbar.com/nanjing/F20/
# http://poi.mapbar.com/nanjing/F21/
# http://poi.mapbar.com/nanjing/F22/
# http://poi.mapbar.com/nanjing/F31/
# http://poi.mapbar.com/nanjing/F40/
# http://poi.mapbar.com/nanjing/F80/
# http://poi.mapbar.com/nanjing/FA0/
# http://poi.mapbar.com/nanjing/FB0/
# http://poi.mapbar.com/nanjing/FC0/
# http://poi.mapbar.com/nanjing/FD0/
# http://poi.mapbar.com/nanjing/FE0/
# http://poi.mapbar.com/nanjing/FF0/
# http://poi.mapbar.com/nanjing/FF1/
# http://poi.mapbar.com/nanjing/FH0/
# http://poi.mapbar.com/nanjing/811/
# http://poi.mapbar.com/nanjing/812/
# http://poi.mapbar.com/nanjing/813/
# http://poi.mapbar.com/nanjing/814/
# http://poi.mapbar.com/nanjing/815/
# http://poi.mapbar.com/nanjing/816/
# http://poi.mapbar.com/nanjing/817/
# http://poi.mapbar.com/nanjing/818/
# http://poi.mapbar.com/nanjing/819/
# http://poi.mapbar.com/nanjing/81A/
# http://poi.mapbar.com/nanjing/81B/
# http://poi.mapbar.com/nanjing/81C/
# http://poi.mapbar.com/nanjing/81D/
# http://poi.mapbar.com/nanjing/820/
# http://poi.mapbar.com/nanjing/82A/
# http://poi.mapbar.com/nanjing/82B/
# http://poi.mapbar.com/nanjing/82C/
# http://poi.mapbar.com/nanjing/82D/
# http://poi.mapbar.com/nanjing/82E/
# http://poi.mapbar.com/nanjing/830/
# http://poi.mapbar.com/nanjing/840/
# http://poi.mapbar.com/nanjing/870/
# http://poi.mapbar.com/nanjing/G11/
# http://poi.mapbar.com/nanjing/G12/
# http://poi.mapbar.com/nanjing/G14/
# http://poi.mapbar.com/nanjing/G15/
# http://poi.mapbar.com/nanjing/G20/
# http://poi.mapbar.com/nanjing/G21/
# http://poi.mapbar.com/nanjing/G30/
# http://poi.mapbar.com/nanjing/G31/
# http://poi.mapbar.com/nanjing/G40/
# http://poi.mapbar.com/nanjing/G50/
# http://poi.mapbar.com/nanjing/G51/
# http://poi.mapbar.com/nanjing/G60/
# http://poi.mapbar.com/nanjing/G70/
# http://poi.mapbar.com/nanjing/G80/
# http://poi.mapbar.com/nanjing/G90/
# http://poi.mapbar.com/nanjing/GA0/
# http://poi.mapbar.com/nanjing/GA1/
# http://poi.mapbar.com/nanjing/GA2/
# http://poi.mapbar.com/nanjing/GD0/
# http://poi.mapbar.com/nanjing/GF0/
# http://poi.mapbar.com/nanjing/B11/
# http://poi.mapbar.com/nanjing/B12/
# http://poi.mapbar.com/nanjing/B13/
# http://poi.mapbar.com/nanjing/B20/
# http://poi.mapbar.com/nanjing/B30/
# http://poi.mapbar.com/nanjing/B40/
# http://poi.mapbar.com/nanjing/B50/
# http://poi.mapbar.com/nanjing/B60/
# http://poi.mapbar.com/nanjing/B70/
# http://poi.mapbar.com/nanjing/B80/
# http://poi.mapbar.com/nanjing/B81/
# http://poi.mapbar.com/nanjing/B83/
# http://poi.mapbar.com/nanjing/B90/
# http://poi.mapbar.com/nanjing/BD0/
